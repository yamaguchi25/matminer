# %%
from matminer.datasets import get_available_datasets

# %%
get_available_datasets()
# Out:
# boltztrap_mp: Effective mass and thermoelectric properties of 8924 compounds in The  Materials Project database that are calculated by the BoltzTraP software package run on the GGA-PBE or GGA+U density functional theory calculation results. The properties are reported at the temperature of 300 Kelvin and the carrier concentration of 1e18 1/cm3.
#
# brgoch_superhard_training: 2574 materials used for training regressors that predict shear and bulk modulus.
#
# castelli_perovskites: 18,928 perovskites generated with ABX combinatorics, calculating gllbsc band gap and pbe structure, and also reporting absolute band edge positions and heat of formation.
#
# citrine_thermal_conductivity: Thermal conductivity of 872 compounds measured experimentally and retrieved from Citrine database from various references. The reported values are measured at various temperatures of which 295 are at room temperature.
#
# ...

# %%
from matminer.datasets import load_dataset

# %%
df = load_dataset("dielectric_constant", data_home=".")

# %%
df.head()
# Out:
#   material_id formula  nsites  space_group      volume  \
# 0      mp-441   Rb2Te       3          225  159.501208
# 1    mp-22881   CdCl2       3          166   84.298097
# 2    mp-28013    MnI2       3          164  108.335875
# 3   mp-567290     LaN       4          186   88.162562
# 4   mp-560902    MnF2       6          136   82.826401
#
#                                            structure  band_gap  \
# 0  [[1.75725875 1.2425695  3.04366125] Rb, [5.271...      1.88
# 1  [[0. 0. 0.] Cd, [ 4.27210959  2.64061969 13.13...      3.52
# 2  [[0. 0. 0.] Mn, [-2.07904300e-06  2.40067320e+...      1.17
# 3  [[-1.73309900e-06  2.38611186e+00  5.95256328e...      1.12
# 4  [[1.677294 2.484476 2.484476] Mn, [0. 0. 0.] M...      2.87
#
#                                         e_electronic  \
# 0  [[3.44115795, -3.097e-05, -6.276e-05], [-2.837...
# 1  [[3.34688382, -0.04498543, -0.22379197], [-0.0...
# 2  [[5.5430849, -5.28e-06, -2.5030000000000003e-0...
# ...

# %%
df.columns
# Out:
# Index(['material_id', 'formula', 'nsites', 'space_group', 'volume',
#        'structure', 'band_gap', 'e_electronic', 'e_total', 'n',
#        'poly_electronic', 'poly_total', 'pot_ferroelectric', 'cif', 'meta',
#        'poscar'],
#       dtype='object')

# %%
df.describe()
# Out:
#             nsites  space_group       volume     band_gap            n  \
# count  1056.000000  1056.000000  1056.000000  1056.000000  1056.000000
# mean      7.530303   142.970644   166.420376     2.119432     2.434886
# std       3.388443    67.264591    97.425084     1.604924     1.148849
# min       2.000000     1.000000    13.980548     0.110000     1.280000
# 25%       5.000000    82.000000    96.262337     0.890000     1.770000
# 50%       8.000000   163.000000   145.944691     1.730000     2.190000
# 75%       9.000000   194.000000   212.106405     2.885000     2.730000
# max      20.000000   229.000000   597.341134     8.320000    16.030000
#
#        poly_electronic   poly_total
# count      1056.000000  1056.000000
# mean          7.248049    14.777898
# std          13.054947    19.435303
# min           1.630000     2.080000
# 25%           3.130000     7.557500
# 50%           4.790000    10.540000
# 75%           7.440000    15.482500
# ...

# %%
df["band_gap"].values
# Out:
# array([1.88, 3.52, 1.17, ..., 0.14, 0.21, 0.26])

# %%
df.iloc[100]
# Out:
# material_id                                                    mp-7140
# formula                                                            SiC
# nsites                                                               4
# space_group                                                        186
# volume                                                       42.005504
# structure            [[-1.87933700e-06  1.78517223e+00  2.53458835e...
# band_gap                                                           2.3
# e_electronic         [[6.9589498, -3.29e-06, 0.0014472600000000001]...
# e_total              [[10.193825310000001, -3.7090000000000006e-05,...
# n                                                                 2.66
# poly_electronic                                                   7.08
# poly_total                                                       10.58
# pot_ferroelectric                                                False
# ...

# %%
mask = df["volume"] >=580

# %%
df[mask]
# Out:
#     material_id formula  nsites  space_group      volume  \
# 206    mp-23280   AsCl3      16           19  582.085309
# 216     mp-9064    RbTe      12          189  590.136085
# 219    mp-23230    PCl3      16           62  590.637274
# 251     mp-2160  Sb2Se3      20           62  597.341134
#
#                                              structure  band_gap  \
# 206  [[0.13113333 7.14863883 9.63476955] As, [2.457...      3.99
# 216  [[6.61780282 0.         0.        ] Rb, [1.750...      0.43
# 219  [[6.02561815 8.74038483 7.55586375] P, [2.7640...      4.03
# 251  [[3.02245275 0.42059268 1.7670481 ] Sb, [ 1.00...      0.76
#
#                                           e_electronic  \
# 206  [[2.2839161900000002, 0.00014519, -2.238000000...
# 216  [[3.25648277, 5.9650000000000007e-05, 1.57e-06...
# 219  [[2.39067769, 0.00017593, 8.931000000000001e-0...
# 251  [[19.1521058, 5.5e-06, 0.00025268], [-1.078000...
#
# ...

# %%
cleaned_df = df.drop(["nsites", "space_group"],axis=1)

# %%
cleaned_df.head()
# Out:
#   material_id formula      volume  \
# 0      mp-441   Rb2Te  159.501208
# 1    mp-22881   CdCl2   84.298097
# 2    mp-28013    MnI2  108.335875
# 3   mp-567290     LaN   88.162562
# 4   mp-560902    MnF2   82.826401
#
#                                            structure  band_gap  \
# 0  [[1.75725875 1.2425695  3.04366125] Rb, [5.271...      1.88
# 1  [[0. 0. 0.] Cd, [ 4.27210959  2.64061969 13.13...      3.52
# 2  [[0. 0. 0.] Mn, [-2.07904300e-06  2.40067320e+...      1.17
# 3  [[-1.73309900e-06  2.38611186e+00  5.95256328e...      1.12
# 4  [[1.677294 2.484476 2.484476] Mn, [0. 0. 0.] M...      2.87
#
#                                         e_electronic  \
# 0  [[3.44115795, -3.097e-05, -6.276e-05], [-2.837...
# 1  [[3.34688382, -0.04498543, -0.22379197], [-0.0...
# 2  [[5.5430849, -5.28e-06, -2.5030000000000003e-0...
# 3  [[7.09316738, 7.99e-06, -0.0003864700000000000...
# 4  [[2.4239622, 7.452000000000001e-05, 6.06100000...
#
# ...

# %%
df["poly_ionic"] = df["poly_total"] - df["poly_electronic"]

# %%
df.head()
# Out:
#   material_id formula  nsites  space_group      volume  \
# 0      mp-441   Rb2Te       3          225  159.501208
# 1    mp-22881   CdCl2       3          166   84.298097
# 2    mp-28013    MnI2       3          164  108.335875
# 3   mp-567290     LaN       4          186   88.162562
# 4   mp-560902    MnF2       6          136   82.826401
#
#                                            structure  band_gap  \
# 0  [[1.75725875 1.2425695  3.04366125] Rb, [5.271...      1.88
# 1  [[0. 0. 0.] Cd, [ 4.27210959  2.64061969 13.13...      3.52
# 2  [[0. 0. 0.] Mn, [-2.07904300e-06  2.40067320e+...      1.17
# 3  [[-1.73309900e-06  2.38611186e+00  5.95256328e...      1.12
# 4  [[1.677294 2.484476 2.484476] Mn, [0. 0. 0.] M...      2.87
#
#                                         e_electronic  \
# 0  [[3.44115795, -3.097e-05, -6.276e-05], [-2.837...
# 1  [[3.34688382, -0.04498543, -0.22379197], [-0.0...
# 2  [[5.5430849, -5.28e-06, -2.5030000000000003e-0...
# ...

# %% [markdown]
# Load and examine the elastic_tensor_2015 dataset

# %%
from matminer.datasets import load_dataset
df=load_dataset("elastic_tensor_2015", data_home=".")

# %%
df.describe()
# Out:
#             nsites  space_group       volume  elastic_anisotropy      G_Reuss  \
# count  1181.000000  1181.000000  1181.000000         1181.000000  1181.000000
# mean     12.425910   163.403895   207.177098            2.145013    64.050568
# std      11.817997    65.040733   192.355747           19.140097    44.696380
# min       2.000000     4.000000    15.850527            0.000005     1.870270
# 25%       5.000000   124.000000    83.944059            0.145030    30.244413
# 50%      10.000000   193.000000   168.920404            0.355287    56.263878
# 75%      16.000000   221.000000   261.420345            0.923117    86.979486
# max     152.000000   229.000000  2398.906164          397.297866   520.845926
#
#              G_VRH      G_Voigt      K_Reuss        K_VRH      K_Voigt  \
# count  1181.000000  1181.000000  1181.000000  1181.000000  1181.000000
# mean     67.543145    71.035720   135.171392   136.259661   137.347932
# ...

# %% [markdown]
# Fileter the dataset based on the number of sites

# %%
from matminer.datasets import load_dataset
df=load_dataset("elastic_tensor_2015", data_home=".")

mask = df["nsites"] < 20
filtered_df=df[mask]

# %%
len(filtered_df)
# Out:
# 975

# %%
filtered_df["nsites"].mean()
# Out:
# 8.554871794871795

# %% [markdown]
# remove columns unnecessary for machine learning

# %%
from matminer.datasets import load_dataset
df=load_dataset("elastic_tensor_2015", data_home=".")
df.drop(["material_id", "nsites"], axis=1)
# Out:
#         formula  space_group      volume  \
# 0       Nb4CoSi          124  194.419802
# 1     Al(CoSi)2          164   61.987320
# 2          SiOs          221   25.952539
# 3            Ga           63   76.721433
# 4         SiRu2           62  160.300999
# ...         ...          ...         ...
# 1176     Ti2CdC          194  121.520152
# 1177       ScSi           63  145.392095
# 1178        YSi           63  174.123748
# 1179      Al2Cu          140  179.147816
# 1180    VCu3Se4          215  180.206796
#
#                                               structure  elastic_anisotropy  \
# 0     [[0.94814328 2.07280467 2.5112    ] Nb, [5.273...            0.030688
# 1     [[0. 0. 0.] Al, [1.96639263 1.13529553 0.75278...            0.266910
# 2      [[1.480346 1.480346 1.480346] Si, [0. 0. 0.] Os]            0.756489
# 3     [[0.         1.09045794 0.84078375] Ga, [0.   ...            2.376805
# 4     [[1.0094265  4.24771709 2.9955487 ] Si, [3.028...            0.196930
# ...

# %%
to_keep = ["formula", "structure", "K_VRH"]
df[to_keep]
# Out:
#         formula                                          structure       K_VRH
# 0       Nb4CoSi  [[0.94814328 2.07280467 2.5112    ] Nb, [5.273...  194.268884
# 1     Al(CoSi)2  [[0. 0. 0.] Al, [1.96639263 1.13529553 0.75278...  175.449907
# 2          SiOs   [[1.480346 1.480346 1.480346] Si, [0. 0. 0.] Os]  295.077545
# 3            Ga  [[0.         1.09045794 0.84078375] Ga, [0.   ...   49.130670
# 4         SiRu2  [[1.0094265  4.24771709 2.9955487 ] Si, [3.028...  256.768081
# ...         ...                                                ...         ...
# 1176     Ti2CdC  [[1.55171489 0.89588144 8.41159136] Ti, [-1.88...  111.788114
# 1177       ScSi  [[0.         8.53417539 0.91740975] Sc, [0.   ...  101.326807
# 1178        YSi  [[0.       9.084549 0.960921] Y, [0.       1.4...   89.418161
# 1179      Al2Cu  [[5.11035838 2.07486738 0.        ] Al, [3.996...   99.384565
# 1180    VCu3Se4  [[0. 0. 0.] V, [0.       2.824189 0.      ] Cu...   35.938660
#
# [1181 rows x 3 columns]
